# %% [markdown]
# ## Librerias

# %%
try:
    import pandas as pd
except ImportError:
    print("Pandas not installed")
    # %pip install pandas --user

try:
    import matplotlib.pyplot as plt
except ImportError:
    print("Matplotlib not installed")
    # %pip install matplotlib --user

import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lectura de datos
#
# - [Dataset Qatar 2022: https://www.kaggle.com/datasets/shrikrishnaparab/fifa-world-cup-2022-qatar-match-data](https://www.kaggle.com/datasets/shrikrishnaparab/fifa-world-cup-2022-qatar-match-data)

# %%
archivo = "https://raw.githubusercontent.com/IgnacioPardo/Tecnologias_Exponenciales_2025/refs/heads/main/qatar.csv"

# Leer datos del archivo
mundial : pd.DataFrame = pd.read_csv(archivo)
mundial
# Out:
#     match_no day_of_week       date   hour                          venue  \
# 0          1         Sun  20-Nov-22  17:00                Al Bayt Stadium
# 1          2         Mon  21-Nov-22  14:00  Khalifa International Stadium
# 2          3         Mon  21-Nov-22  17:00             Al Thumama Stadium
# 3          4         Mon  21-Nov-22  20:00          Ahmed bin Ali Stadium
# 4          5         Tue  22-Nov-22  11:00          Lusail Iconic Stadium
# ..       ...         ...        ...    ...                            ...
# 59        60         Sat  10-Dec-22  20:00                Al Bayt Stadium
# 60        61         Tue  13-Dec-22  20:00          Lusail Iconic Stadium
# 61        62         Wed  14-Dec-22  20:00                Al Bayt Stadium
# 62        63         Sat  17-Dec-22  16:00  Khalifa International Stadium
# 63        64         Sun  18-Dec-22  16:00          Lusail Iconic Stadium
#
#                           referee                     group              1  \
# ...

# %%
# Cuantos partidos se jugaron?
# Completar

Total_Partidos = mundial['match_no'].count()
Total_Partidos
# Out:
# 64

# %%
# Que datos tiene el dataset? (Pista: usar .info(), .describe(), .columns, .head())
# Checkear columnas
# Completar

mundial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 59 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   match_no                         64 non-null     int64
#  1   day_of_week                      64 non-null     object
#  2   date                             64 non-null     object
#  3   hour                             64 non-null     object
#  4   venue                            64 non-null     object
#  5   referee                          64 non-null     object
#  6   group                            64 non-null     object
#  7   1                                64 non-null     object
#  8   2                                64 non-null     object
#  9   attendance                       64 non-null     int64
#  10  1_xg                             64 non-null     float64
#  11  2_xg                             64 non-null     float64
# ...

# %%
mundial.describe()
# Out:
#         match_no    attendance       1_xg       2_xg     1_poss     2_poss  \
# count  64.000000     64.000000  64.000000  64.000000  64.000000  64.000000
# mean   32.500000  53191.437500   1.379687   1.270312  50.890625  49.109375
# std    18.618987  17108.666048   0.889655   0.953636  12.744270  12.744270
# min     1.000000  39089.000000   0.100000   0.000000  18.000000  19.000000
# 25%    16.750000  42424.000000   0.700000   0.600000  41.750000  40.750000
# 50%    32.500000  44093.000000   1.250000   1.100000  53.000000  47.000000
# 75%    48.250000  66851.500000   1.825000   1.700000  59.250000  58.250000
# max    64.000000  88966.000000   4.000000   5.700000  81.000000  82.000000
#
#          1_goals    2_goals  1_attempts  2_attempts  ...  1_panelties_scored  \
# count  64.000000  64.000000   64.000000   64.000000  ...           64.000000
# mean    1.578125   1.109375   11.140625   11.281250  ...            0.140625
# ...

# %%
mundial.columns
# Out:
# Index(['match_no', 'day_of_week', 'date', 'hour', 'venue', 'referee', 'group',
#        '1', '2', 'attendance', '1_xg', '2_xg', '1_poss', '2_poss', '1_goals',
#        '2_goals', 'score', '1_attempts', '2_attempts', '1_conceded',
#        '2_conceded', '1_goal_inside_penalty_area',
#        '2_goal_inside_penalty_area', '1_goal_outside_penalty_area',
#        '2_goal_outside_penalty_area', '1_ontarget', '2_ontarget',
#        '1_offtarget', '2_offtarget', '1_attempts_inside_penalty_area',
#        '2_attempts_inside_penalty_area', '1_attempts_outside_penalty_area',
#        '2_attempts_outside_penalty_area', '1_yellow_cards', '2_yellow_cards',
#        '1_red_cards', '2_red_cards', 'faul_against_1', 'faul_against_2',
#        '1_offsides', '2_offsides', '1_passes', '2_passes',
#        '1_passes_compeletd', '2_passes_compeletd', '1_corners', '2_corners',
#        '1_free_kicks', '2_free_kicks', '1_panelties_scored',
# ...

# %%
mundial.head()
# Out:
#    match_no day_of_week       date   hour                          venue  \
# 0         1         Sun  20-Nov-22  17:00                Al Bayt Stadium
# 1         2         Mon  21-Nov-22  14:00  Khalifa International Stadium
# 2         3         Mon  21-Nov-22  17:00             Al Thumama Stadium
# 3         4         Mon  21-Nov-22  20:00          Ahmed bin Ali Stadium
# 4         5         Tue  22-Nov-22  11:00          Lusail Iconic Stadium
#
#                          referee    group              1             2  \
# 0                 Daniele Orsato  Group A          QATAR       ECUADOR
# 1                  Raphael Claus  Group B        ENGLAND          IRAN
# 2                 Wilton Sampaio  Group A        SENEGAL   NETHERLANDS
# 3  Abdulrahman Ibrahim Al Jassim  Group B  UNITED STATES         WALES
# 4                  Slavko Vincic  Group C      ARGENTINA  SAUDI ARABIA
#
#    attendance  ...  1_panelties_scored  2_panelties_scored  1_goal_prevented  \
# ...

# %% [markdown]
# ## Analisis

# %% [markdown]
# ### Primera Parte

# %%
# Cuantas selecciones participaron?
# Completar

Total_Selecciones = pd.concat([mundial['1'], mundial['2']]).nunique()
Total_Selecciones
# Out:
# 32

# %%
# Cuantas fases tiene el mundial?
# Completar

Fases = mundial['group'].nunique()
Fases
# Out:
# 13

# %%
# Cual fue la "attendance" promedio por partido?
# Completar

Attendance_Promedio = mundial['attendance'].mean()
Attendance_Promedio
# Out:
# 53191.4375

# %%
# Cual fue el partido con mas diferencia de goles?
# Completar

mundial['Diferencia_Goles'] = (mundial['1_goals'] - mundial['2_goals'])

Mayor_Diferencia = mundial['Diferencia_Goles'].max()

Partido_Mayor_Diferencia = mundial[mundial['Diferencia_Goles'] == Mayor_Diferencia]

Partido_Mayor_Diferencia
# Out:
#     match_no day_of_week       date   hour               venue  \
# 10        11         Wed  23-Nov-22  17:00  Al Thumama Stadium
#
#                     referee    group      1           2  attendance  ...  \
# 10  Mohammed Abdulla Hassan  Group E  SPAIN  COSTA RICA       40013  ...
#
#     2_panelties_scored  1_goal_prevented  2_goal_prevented  1_own_goal  \
# 10                   0                 0                17           0
#
#     2_own_goal  1_forced_turnovers 2_forced_turnovers  \
# 10           0                  46                 76
#
#     1_defensive_pressure_applied  2_defensive_pressure_applied  \
# 10                           185                           585
#
#     Diferencia_Goles
# 10                 7
#
# [1 rows x 60 columns]

# %%
# Cual es la selección que mas penales metió?
# Completar

Penales_Equipo1 = mundial.groupby('1')['1_panelties_scored'].sum()
Penales_Equipo2 = mundial.groupby('2')['2_panelties_scored'].sum()

Total_Penales = Penales_Equipo1 + Penales_Equipo2

Total_Penales
# Out:
# 1
# ARGENTINA         4
# AUSTRALIA         0
# BELGIUM           0
# BRAZIL            1
# CAMEROON          0
# CANADA            0
# COSTA RICA        0
# CROATIA           0
# DENMARK           0
# ECUADOR           1
# ENGLAND           1
# FRANCE            2
# GERMANY           1
# GHANA             0
# IRAN              1
# JAPAN             0
# KOREA REPUBLIC    0
# MEXICO            0
# MOROCCO           0
# NETHERLANDS       0
# POLAND            1
# PORTUGAL          2
# QATAR             0
# SAUDI ARABIA      0
# SENEGAL           1
# SERBIA            0
# SPAIN             1
# SWITZERLAND       0
# TUNISIA           0
# UNITED STATES     0
# URUGUAY           0
# WALES             1
# dtype: int64

# %%
# Cual es la selección que mas penales le hicieron?
# Completar

Penales_Equipo1 = mundial.groupby('1')['1_panelties_scored'].sum()
Penales_Equipo2 = mundial.groupby('2')['2_panelties_scored'].sum()

Total_Penales_Recibidos = Penales_Equipo1 - Penales_Equipo2

print("Selección con más penales:", Total_Penales_Recibidos.idxmin())

print("Cantidad de penales:", Total_Penales.max())

Total_Penales_Recibidos
# Out:
# Selección con más penales: FRANCE
# Cantidad de penales: 4
# 1
# ARGENTINA         2
# AUSTRALIA         0
# BELGIUM           0
# BRAZIL            1
# CAMEROON          0
# CANADA            0
# COSTA RICA        0
# CROATIA           0
# DENMARK           0
# ECUADOR          -1
# ENGLAND           1
# FRANCE           -2
# GERMANY           1
# GHANA             0
# IRAN             -1
# JAPAN             0
# KOREA REPUBLIC    0
# MEXICO            0
# MOROCCO           0
# NETHERLANDS       0
# POLAND           -1
# PORTUGAL          2
# QATAR             0
# SAUDI ARABIA      0
# SENEGAL          -1
# SERBIA            0
# SPAIN             1
# SWITZERLAND       0
# TUNISIA           0
# UNITED STATES     0
# URUGUAY           0
# WALES            -1
# dtype: int64

# %% [markdown]
# ### Segunda Parte

# %%
equipo : str = "ARGENTINA"

# %%
# Seleccionar todos los partidos que jugo el equipo de "local"
# Completar

filtrolocal : pd.Series = mundial['1'] == equipo
Partidos_Local = mundial[filtrolocal]
Partidos_Local
# Out:
#     match_no day_of_week       date   hour                  venue  \
# 4          5         Tue  22-Nov-22  11:00  Lusail Iconic Stadium
# 23        24         Sat  26-Nov-22  20:00  Lusail Iconic Stadium
# 49        50         Sat   3-Dec-22  20:00  Ahmed bin Ali Stadium
# 60        61         Tue  13-Dec-22  20:00  Lusail Iconic Stadium
# 63        64         Sun  18-Dec-22  16:00  Lusail Iconic Stadium
#
#              referee        group          1             2  attendance  ...  \
# 4      Slavko Vincic      Group C  ARGENTINA  SAUDI ARABIA       88012  ...
# 23    Daniele Orsato      Group C  ARGENTINA        MEXICO       88966  ...
# 49  Szymon Marciniak  Round of 16  ARGENTINA     AUSTRALIA       45032  ...
# 60    Daniele Orsato   Semi-Final  ARGENTINA       CROATIA       88966  ...
# 63  Szymon Marciniak        Final  ARGENTINA        FRANCE       88966  ...
#
#     2_panelties_scored  1_goal_prevented  2_goal_prevented  1_own_goal  \
# ...

# %%
# Seleccionar todos los partidos que jugo el equipo de "visitante"
# Completar

filtroVisitante : pd.Series = mundial['2'] == equipo
Partidos_Visitante = mundial[filtroVisitante]
Partidos_Visitante
# Out:
#     match_no day_of_week       date   hour                  venue  \
# 38        39         Wed  30-Nov-22  20:00  Lusail Iconic Stadium
# 57        58         Fri   9-Dec-22  20:00  Lusail Iconic Stadium
#
#                 referee          group            1          2  attendance  \
# 38       Michael Oliver        Group C       POLAND  ARGENTINA       84985
# 57  Antonio Mateu Lahoz  Quarter-final  NETHERLANDS  ARGENTINA       88235
#
#     ...  2_panelties_scored  1_goal_prevented  2_goal_prevented  1_own_goal  \
# 38  ...                   0                25                 4           0
# 57  ...                   1                15                 5           0
#
#     2_own_goal  1_forced_turnovers 2_forced_turnovers  \
# 38           0                  67                 48
# 57           0                  91                 79
#
#     1_defensive_pressure_applied  2_defensive_pressure_applied  \
# 38                           438                           141
# ...

# %%
# Seleccionar todos los partidos que jugo el equipo (de "local" o "visitante")
# Completar

partidos : pd.DataFrame = pd.concat([Partidos_Local, Partidos_Visitante])
partidos
# Out:
#     match_no day_of_week       date   hour                  venue  \
# 4          5         Tue  22-Nov-22  11:00  Lusail Iconic Stadium
# 23        24         Sat  26-Nov-22  20:00  Lusail Iconic Stadium
# 49        50         Sat   3-Dec-22  20:00  Ahmed bin Ali Stadium
# 60        61         Tue  13-Dec-22  20:00  Lusail Iconic Stadium
# 63        64         Sun  18-Dec-22  16:00  Lusail Iconic Stadium
# 38        39         Wed  30-Nov-22  20:00  Lusail Iconic Stadium
# 57        58         Fri   9-Dec-22  20:00  Lusail Iconic Stadium
#
#                 referee          group            1             2  attendance  \
# 4         Slavko Vincic        Group C    ARGENTINA  SAUDI ARABIA       88012
# 23       Daniele Orsato        Group C    ARGENTINA        MEXICO       88966
# 49     Szymon Marciniak    Round of 16    ARGENTINA     AUSTRALIA       45032
# 60       Daniele Orsato     Semi-Final    ARGENTINA       CROATIA       88966
# ...

# %%
# Cuantos goles hizo el equipo en total (obtener los goles metidos de local y sumarlos con los goles metidos de visitante)
# Completar

goles : int = Partidos_Local['1_goals'].sum() + Partidos_Visitante['2_goals'].sum()
goles
# Out:
# 15

# %%
# Cuantos goles hizo el equipo en promedio
# Completar

Total_Partidos_Equipo : int = len(partidos)
Promedio_Goles = goles / Total_Partidos_Equipo
Promedio_Goles
# Out:
# 2.142857142857143

# %%
# Cuantos partidos gano el equipo
# Completar

ganados : int = ((Partidos_Local['1_goals'] > Partidos_Local['2_goals']).sum() + (Partidos_Visitante['2_goals'] > Partidos_Visitante['1_goals']).sum())
ganados
# Out:
# 4

# %%
# Graficar los goles hechos por el equipo en cada partido

# Graficar goles por partido

goles_pp = [r['1_goals'] if r['1'] == equipo else r['2_goals'] for _, r in partidos.iterrows()]
rivales  = [f"vs {r['2']}" if r['1'] == equipo else f"vs {r['1']}" for _, r in partidos.iterrows()]

fig, ax = plt.subplots(figsize=(10, 4))
ax.bar(rivales, goles_pp, color='lightblue', edgecolor='steelblue')
ax.set_title(f"Goles de {equipo} por partido")
ax.set_ylabel("Goles")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Tercera Parte

# %%
# Contar cuantos goles hizo cada equipo en total en el mundial
# Completar

equipos = pd.concat([mundial["1"], mundial["2"]]).unique()

goles = []

for equipo in equipos:

    goles_local = mundial[
        mundial["1"] == equipo
    ]["1_goals"].sum()

    goles_visitante = mundial[
        mundial["2"] == equipo
    ]["2_goals"].sum()

    total = goles_local + goles_visitante

    goles.append(total)

print(equipos)

print(goles)
# Out:
# ['QATAR' 'ENGLAND' 'SENEGAL' 'UNITED STATES' 'ARGENTINA' 'DENMARK'
#  'MEXICO' 'FRANCE' 'MOROCCO' 'GERMANY' 'SPAIN' 'BELGIUM' 'SWITZERLAND'
#  'URUGUAY' 'PORTUGAL' 'BRAZIL' 'WALES' 'NETHERLANDS' 'TUNISIA' 'POLAND'
#  'JAPAN' 'CROATIA' 'CAMEROON' 'KOREA REPUBLIC' 'ECUADOR' 'IRAN'
#  'AUSTRALIA' 'SAUDI ARABIA' 'CANADA' 'COSTA RICA' 'GHANA' 'SERBIA']
# [1, 13, 5, 3, 15, 1, 2, 16, 6, 6, 9, 1, 5, 2, 12, 8, 1, 10, 1, 3, 5, 8, 4, 5, 4, 4, 4, 3, 2, 3, 5, 5]

# %%
# Graficar los goles por equipo en todo el mundial

# Completar

fig, ax = plt.subplots(figsize=(14, 5))
goles_totales.plot(kind='bar', ax=ax, color='steelblue')
ax.set_title("Goles por equipo - Qatar 2022")
ax.set_ylabel("Goles")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Cual es el equipo que hizo mas goles en el mundial?
# Completar

print(goles_totales.idxmax(), goles_totales.max())
# Out:
# FRANCE 16

# %%
# Por cada partido, cual fue la diferencia de goles?
# Completar

mundial['diferencia'] = abs(mundial['1_goals'] - mundial['2_goals'])
mundial[['match_no', '1', '2', '1_goals', '2_goals', 'diferencia']]
# Out:
#     match_no              1             2  1_goals  2_goals  diferencia
# 0          1          QATAR       ECUADOR        0        2           2
# 1          2        ENGLAND          IRAN        6        2           4
# 2          3        SENEGAL   NETHERLANDS        0        2           2
# 3          4  UNITED STATES         WALES        1        1           0
# 4          5      ARGENTINA  SAUDI ARABIA        1        2           1
# ..       ...            ...           ...      ...      ...         ...
# 59        60        ENGLAND        FRANCE        1        2           1
# 60        61      ARGENTINA       CROATIA        3        0           3
# 61        62         FRANCE       MOROCCO        2        0           2
# 62        63        CROATIA       MOROCCO        2        1           1
# 63        64      ARGENTINA        FRANCE        3        3           0
#
# [64 rows x 6 columns]

# %%
# Por cada partido, cual fue el equipo que gano?
# Completar

def ganador(r):
    if r['1_goals'] > r['2_goals']: return r['1']
    if r['2_goals'] > r['1_goals']: return r['2']
    return 'EMPATE'

mundial['ganador'] = mundial.apply(ganador, axis=1)
mundial[['match_no', '1', '2', '1_goals', '2_goals', 'ganador']]
# Out:
#     match_no              1             2  1_goals  2_goals       ganador
# 0          1          QATAR       ECUADOR        0        2       ECUADOR
# 1          2        ENGLAND          IRAN        6        2       ENGLAND
# 2          3        SENEGAL   NETHERLANDS        0        2   NETHERLANDS
# 3          4  UNITED STATES         WALES        1        1        EMPATE
# 4          5      ARGENTINA  SAUDI ARABIA        1        2  SAUDI ARABIA
# ..       ...            ...           ...      ...      ...           ...
# 59        60        ENGLAND        FRANCE        1        2        FRANCE
# 60        61      ARGENTINA       CROATIA        3        0     ARGENTINA
# 61        62         FRANCE       MOROCCO        2        0        FRANCE
# 62        63        CROATIA       MOROCCO        2        1       CROATIA
# 63        64      ARGENTINA        FRANCE        3        3        EMPATE
#
# [64 rows x 6 columns]

# %%
# En cada fase del mundial, cual fue el equipo que hizo mas goles?
# Completar

for fase, df in mundial.groupby('group'):
    g = df.groupby('1')['1_goals'].sum().add(df.groupby('2')['2_goals'].sum(), fill_value=0)
    print(f"{fase}: {g.idxmax()} ({int(g.max())} goles)")
# Out:
# Final: ARGENTINA (3 goles)
# Group A: NETHERLANDS (5 goles)
# Group B: ENGLAND (9 goles)
# Group C: ARGENTINA (5 goles)
# Group D: FRANCE (6 goles)
# Group E: SPAIN (9 goles)
# Group F: CROATIA (4 goles)
# Group G: SERBIA (5 goles)
# Group H: PORTUGAL (6 goles)
# Play-off for third place: CROATIA (2 goles)
# Quarter-final: ARGENTINA (2 goles)
# Round of 16: PORTUGAL (6 goles)
# Semi-Final: ARGENTINA (3 goles)

# %% [markdown]
# ### Tercera Parte

# %%
# Armar un gráfico a partir de algun nuevo análisis que se te ocurra
# Completar

equipos = pd.concat([mundial["1"], mundial["2"]]).unique()

amarillas = []

for equipo in equipos:

    amarillas_local = mundial[
        mundial["1"] == equipo
    ]["1_yellow_cards"].sum()

    amarillas_visitante = mundial[
        mundial["2"] == equipo
    ]["2_yellow_cards"].sum()

    total = amarillas_local + amarillas_visitante

    amarillas.append(total)

fig, ax = plt.subplots(figsize=(15,6))

ax.bar(equipos, amarillas)

ax.set_title("Tarjetas amarillas por equipo")
ax.set_xlabel("Equipos")
ax.set_ylabel("Tarjetas amarillas")
ax.bar(equipos, amarillas, color="yellow")

plt.xticks(rotation=90)

plt.show()
